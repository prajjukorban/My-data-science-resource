# %% [markdown]
# ## Topics
# - DataFrame
# - import data
# - Attribute & Function
# - Handling missing data
# - practice

# %%
import pandas as pd

# %% [markdown]
# ## Series is 1D

# %%
series = pd.Series(["Audi","BMW","Nexa"])

# %%
series
# Out:
# 0    Audi
# 1     BMW
# 2    Nexa
# dtype: object

# %% [markdown]
# ## DataFrame is 2D

# %%
car = pd.DataFrame({"Brand":series,"Price":["50L","60L","15L"]})

# %%
car
# Out:
#   Brand Price
# 0  Audi   50L
# 1   BMW   60L
# 2  Nexa   15L

# %% [markdown]
# ## Import data

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %% [markdown]
# ## importing data from URL

# %%
car_sales_url = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")

# %%
car_sales_url.head(1)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
#
#    ca  thal  target
# 0   0     1       1

# %% [markdown]
# ## Describe Data

# %% [markdown]
#  ## Attribute      ,    Function
# car_sales.dtypes  ,  car_sales.to_csv()

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.mean(numeric_only=True) #new update
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales['Doors'].std()
# Out:
# 0.4714045207910317

# %%
car_sales[car_sales["Make"] == "Nissan"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 4  Nissan  White         213095      4  $3,500.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.groupby(["Colour","Make"]).count()
# Out:
#                Odometer (KM)  Doors  Price
# Colour Make
# Black  BMW                 1      1      1
# Blue   Honda               2      2      2
#        Toyota              1      1      1
# Green  Toyota              1      1      1
# Red    Honda               1      1      1
# White  Nissan              2      2      2
#        Toyota              2      2      2

# %% [markdown]
# ## Manuplating Data in Pandas

# %%
car_s_missing = pd.read_csv("car-sales-missing-data.csv")
car_s_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_s_missing['Odometer'] = round(car_s_missing["Odometer"].fillna(car_s_missing.Odometer.mean(numeric_only=True)),1)

# %%
car_s_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue   92302.7    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green   92302.7    4.0   $4,500
# 6   Honda    NaN   92302.7    4.0   $7,500
# 7   Honda   Blue   92302.7    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales["seat"] = pd.Series([5,5,5,5,5])

# %%
car_sales.fillna(5,inplace=True)

# %%
car_sales["Milage/ltr"] = [25,30,18,33,15,22,19,23,12,26]

# %%
car_sales["Toatal Fuel Used in ltr"] = car_sales["Odometer (KM)"]/car_sales["Milage/ltr"]

# %%
car_sales["Total Money on fuel in $"] = car_sales["Toatal Fuel Used in ltr"] * 1.25

# %% [markdown]
# ## Project

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seat  Milage/ltr  \
# 0  Toyota  White         150043      4   $4,000.00   5.0          25
# 1   Honda    Red          87899      4   $5,000.00   5.0          30
# 2  Toyota   Blue          32549      3   $7,000.00   5.0          18
# 3     BMW  Black          11179      5  $22,000.00   5.0          33
# 4  Nissan  White         213095      4   $3,500.00   5.0          15
# 5  Toyota  Green          99213      4   $4,500.00   5.0          22
# 6   Honda   Blue          45698      4   $7,500.00   5.0          19
# 7   Honda   Blue          54738      4   $7,000.00   5.0          23
# 8  Toyota  White          60000      4   $6,250.00   5.0          12
# 9  Nissan  White          31600      4   $9,700.00   5.0          26
#
#    Toatal Fuel Used in ltr  Total Money on fuel in $
# 0              6001.720000               7502.150000
# 1              2929.966667               3662.458333
# 2              1808.277778               2260.347222
# 3               338.757576                423.446970
# 4             14206.333333              17757.916667
# 5              4509.681818               5637.102273
# 6              2405.157895               3006.447368
# 7              2379.913043               2974.891304
# 8              5000.000000               6250.000000
# 9              1215.384615               1519.230769

# %%
import random
# Assuming car_sales is your DataFrame
car_sales["Safety Rating"] = [random.uniform(4.5, 5) for _ in range(10)]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price